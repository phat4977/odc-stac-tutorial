# %% [markdown]
# #  Drawing polygon to create training data <img align="right" src="image/gistda.png" width="200" height="200">
#
#  - [Display interactive map](#Display-interactive-map)
#  - [Display output from drawing](#Display-output-from-drawing)
#  - [Add new column](#Add-new-column)
#  - [Merge data](#Merge-data)
#  - [Convert geographic coordinate system](#convert-geographic-coordinate-system)
#
# <table class="ee-notebook-buttons" align="left">
#     <td><a target="_parent"  href="https://nbviewer.org/github/Pathakorn40/rice-detection/blob/main/Tutorial/Drawing_polygon.ipynb"><img width=26px src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/883px-Jupyter_logo.svg.png" />Notebook Viewer</a></td>
# </table>

# %% [markdown]
# ### Display interactive map

# %% [markdown]
# This case study draw the polygon to create training data for ML classification.
# - Draw polygons from the tools in left side and export file by `Export` buttom on the right side .
# - This case study, we catagorize training data into three classes that compose of urban area, water area and green area.
# - The output will save in GeoJson file format.
#
# We draw the polygon in 3 files name: green_area_sawan.geojson, water_sawan.geojson,and urban_sawan.geojson.

# %%
from dream_river.plotimg import show_map

Map = show_map()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38333d98134615075e673908b893a8da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38333d98134615075e673908b893a8da&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38333d98134615075e673908b893a8da = L.map(
#                 &quot;map_38333d98134615075e673908b893a8da&quot;,
#                 {
#                     center: [13.726, 100.514],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;show&quot;: true}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_38333d98134615075e673908b893a8da.setView(e.geocode.center, 11);
#             }).addTo(map_38333d98134615075e673908b893a8da);
#
#
#
#             var locate_control_10b6c2fe8ef5815e30a925d7e52d66a8 = L.control.locate(
#                 {}
#             ).addTo(map_38333d98134615075e673908b893a8da);
#
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_38333d98134615075e673908b893a8da);
#
#
#             var marker_44f12aac289a403288f4fe7600dc0f45 = L.marker(
#                 [13.726, 100.514],
#                 {}
#             ).addTo(map_38333d98134615075e673908b893a8da);
#
#
#             var icon_7a774d510da50e9af0c72229c684ee29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_44f12aac289a403288f4fe7600dc0f45.setIcon(icon_7a774d510da50e9af0c72229c684ee29);
#
#
#             var tile_layer_f4f417c9faf7b2a720590916f157a72d = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38333d98134615075e673908b893a8da);
#
#
#             var tile_layer_2a5af9c6e8972771c015acfca7ad6f25 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=p\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38333d98134615075e673908b893a8da);
#
#
#             var tile_layer_4e814de36f230d782ed7dfea3a36fe2a = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38333

# %% [markdown]
# ## Display output from drawing

# %%
from dream_river.plotimg import show_vector

# get path of files
path = ['training/green_area_sawan.geojson','training/water_sawan.geojson','training/urban_sawan.geojson']
show_vector(path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df12a7b4c8f0962ce7edf6c1021f57be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df12a7b4c8f0962ce7edf6c1021f57be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df12a7b4c8f0962ce7edf6c1021f57be = L.map(
#                 &quot;map_df12a7b4c8f0962ce7edf6c1021f57be&quot;,
#                 {
#                     center: [15.716456999999998, 100.1213375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#         function geo_json_a4c9cf89c6f5e646acd5c16ed85a0159_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;lime&quot;, &quot;fillOpacity&quot;: 0.2};
#             }
#         }
#
#         function geo_json_a4c9cf89c6f5e646acd5c16ed85a0159_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a4c9cf89c6f5e646acd5c16ed85a0159 = L.geoJson(null, {
#                 onEachFeature: geo_json_a4c9cf89c6f5e646acd5c16ed85a0159_onEachFeature,
#
#                 style: geo_json_a4c9cf89c6f5e646acd5c16ed85a0159_styler,
#         });
#
#         function geo_json_a4c9cf89c6f5e646acd5c16ed85a0159_add (data) {
#             geo_json_a4c9cf89c6f5e646acd5c16ed85a0159
#                 .addData(data)
#                 .addTo(map_df12a7b4c8f0962ce7edf6c1021f57be);
#         }
#             geo_json_a4c9cf89c6f5e646acd5c16ed85a0159_add({&quot;bbox&quot;: [100.097696, 15.697438, 100.135955, 15.726924], &quot;features&quot;: [{&quot;bbox&quot;: [100.120683, 15.715997, 100.121992, 15.716917], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.120683, 15.715997], [100.120683, 15.716917], [100.121992, 15.716917], [100.121992, 15.715997], [100.120683, 15.715997]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.132914, 15.717717, 100.134019, 15.718538], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.132914, 15.717717], [100.132914, 15.718538], [100.134019, 15.718538], [100.134019, 15.717717], [100.132914, 15.717717]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.13212, 15.713514, 100.132951, 15.713947], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.13212, 15.713514], [100.13212, 15.713947], [100.132951, 15.713947], [100.132951, 15.713514], [100.13212, 15.713514]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.134963, 15.712553, 100.135869, 15.713002], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.134963, 15.712754], [100.135043, 15.712553], [100.135869, 15.712816], [100.135805, 15.713002], [100.134963, 15.712754]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.133917, 15.71246, 100.134518, 15.712884], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.133954, 15.712718], [100.134437, 15.712884], [100.134518, 15.712718], [100.134394, 15.712641], [100.134432, 15.712543], [100.134287, 15.71246], [100.134003, 15.712594], [100.133917, 15.712662], [100.133954, 15.712718]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.123757, 15.70586, 100.124518, 15.706315], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.123757, 15.70586], [100.123757, 15.706315], [100.124518, 15.706315], [100.124518, 15.70586], [100.123757, 15.70586]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.124186, 15.707993, 100.12499, 15.708701], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.124186, 15.707993], [100.124186, 15.708701], [100.12499, 15.708701], [100.12499, 15.707993], [100.124186, 15.707993]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.124668, 15.709315, 100.124974, 15.709506], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.124668, 15.709315], [100.124668, 15.709506], [100.124974, 15.709506], [100.124974, 15.709315], [100.124668, 15.709315]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.12602, 15.709857, 100.126369, 15.710105], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.12602, 15.709857], [100.12602, 15.710105], [100.126369, 15.710105], [100.126369, 15.709857], [100.12602, 15.709857]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;8&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.132908, 15.706945, 100.133262, 15.707183], &quot;geometry

# %% [markdown]
# ### Data preparation

# %%
import geopandas as gpd

# open file in geopandas dataframe
gdf = gpd.read_file('training/green_area_sawan.geojson')

# to see 5 first rows
gdf.head()
# Out:
#    class                                           geometry
# 0    111  POLYGON ((100.12068 15.71600, 100.12068 15.716...
# 1    111  POLYGON ((100.13291 15.71772, 100.13291 15.718...
# 2    111  POLYGON ((100.13212 15.71351, 100.13212 15.713...
# 3    111  POLYGON ((100.13496 15.71275, 100.13504 15.712...
# 4    111  POLYGON ((100.13395 15.71272, 100.13444 15.712...

# %% [markdown]
# As you can see the table above, It do not have any unique value for identify the class type.

# %% [markdown]
# ### Add new column
# - to categorize the type of polygon files for creating training data
# - first, input the name of new column. Then assign the code value to identify the type of that file.
#
# In this case study, we create "class" column and add value into that column follow file name to categorize the type of data like:
#
# green_area = 111
#
# water = 112
#
# urban = 113

# %%
from dream_river.plotimg import geojson_add_Newcol

# func to add new colume and assign value
geojson_add_Newcol('training/green_area_sawan.geojson')
# Out:
# num of rows:  20
# Enter the name of the new column:  class
# Enter the value for the new column:  111
# 20

# %%
# func to add new colume and assign value
geojson_add_Newcol('training/water_sawan.geojson')
# Out:
# num of rows:  14
# Enter the name of the new column:  class
# Enter the value for the new column:  112
# 14

# %%
# func to add new colume and assign value
geojson_add_Newcol('training/urban_sawan.geojson')
# Out:
# num of rows:  18
# Enter the name of the new column:  class
# Enter the value for the new column:  113
# 18

# %% [markdown]
# ### Explore output

# %%
import geopandas as gpd

gdf = gpd.read_file('training/urban_sawan.geojson')

# gdf.head(50)
gdf.head()
# Out:
#    class                                           geometry
# 0    113  POLYGON ((100.13354 15.70495, 100.13372 15.705...
# 1    113  POLYGON ((100.13938 15.70688, 100.13843 15.704...
# 2    113  POLYGON ((100.14057 15.70553, 100.13964 15.704...
# 3    113  POLYGON ((100.14808 15.71282, 100.14808 15.714...
# 4    113  POLYGON ((100.15108 15.71813, 100.15100 15.717...

# %%
# check coordinate system of data
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Merge data
# Note : It will take a few secound second to create file.

# %%
from dream_river.geobox import merge

# assige input path
file =['training/green_area_sawan.geojson','training/urban_sawan.geojson','training/water_sawan.geojson']

# assign output file path
output = 'training/training_data.geojson'

# merge function
merge(file,output)

# %% [markdown]
# ### Explore output

# %%
gdf = gpd.read_file('training/training_data.geojson')

gdf.head(25)
# gdf.head()
# Out:
#     class                                           geometry
# 0     111  POLYGON ((100.12068 15.71600, 100.12068 15.716...
# 1     111  POLYGON ((100.13291 15.71772, 100.13291 15.718...
# 2     111  POLYGON ((100.13212 15.71351, 100.13212 15.713...
# 3     111  POLYGON ((100.13496 15.71275, 100.13504 15.712...
# 4     111  POLYGON ((100.13395 15.71272, 100.13444 15.712...
# 5     111  POLYGON ((100.12376 15.70586, 100.12376 15.706...
# 6     111  POLYGON ((100.12419 15.70799, 100.12419 15.708...
# 7     111  POLYGON ((100.12467 15.70932, 100.12467 15.709...
# 8     111  POLYGON ((100.12602 15.70986, 100.12602 15.710...
# 9     111  POLYGON ((100.13291 15.70694, 100.13291 15.707...
# 10    111  POLYGON ((100.13556 15.70449, 100.13529 15.703...
# 11    111  POLYGON ((100.11181 15.70125, 100.11181 15.702...
# 12    111  POLYGON ((100.10953 15.70873, 100.10953 15.709...
# 13    111  POLYGON ((100.10743 15.71212, 100.10743 15.712...
# 14    111  POLYGON ((100.11135 15.71299, 100.11135 15.713...
# 15    111  POLYGON ((100.10132 15.71485, 100.10132 15.715...
# 16    111  POLYGON ((100.12456 15.71932, 100.12456 15.720...
# 17    111  POLYGON ((100.12250 15.72322, 100.12250 15.723...
# 18    111  POLYGON ((100.12178 15.72668, 100.12178 15.726...
# 19    111  POLYGON ((100.09770 15.69744, 100.09770 15.697...
# 20    113  POLYGON ((100.13354 15.70495, 100.13372 15.705...
# 21    113  POLYGON ((100.13938 15.70688, 100.13843 15.704...
# 22    113  POLYGON ((100.14057 15.70553, 100.13964 15.704...
# 23    113  POLYGON ((100.14808 15.71282, 100.14808 15.714...
# 24    113  POLYGON ((100.15108 15.71813, 100.15100 15.717...

# %%
from dream_river.plotimg import show_vector

path = ['training/training_data.geojson']
show_vector(path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e1356009eba77cd9145272101c72c47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e1356009eba77cd9145272101c72c47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e1356009eba77cd9145272101c72c47 = L.map(
#                 &quot;map_0e1356009eba77cd9145272101c72c47&quot;,
#                 {
#                     center: [15.716456999999998, 100.1213375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#         function geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;lime&quot;, &quot;fillOpacity&quot;: 0.2};
#             }
#         }
#
#         function geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4 = L.geoJson(null, {
#                 onEachFeature: geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4_onEachFeature,
#
#                 style: geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4_styler,
#         });
#
#         function geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4_add (data) {
#             geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4
#                 .addData(data)
#                 .addTo(map_0e1356009eba77cd9145272101c72c47);
#         }
#             geo_json_a8b5a846ae8eeaeaf7ed44d3baf48cb4_add({&quot;bbox&quot;: [100.07376, 15.671873, 100.152483, 15.732857], &quot;features&quot;: [{&quot;bbox&quot;: [100.120683, 15.715997, 100.121992, 15.716917], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.120683, 15.715997], [100.120683, 15.716917], [100.121992, 15.716917], [100.121992, 15.715997], [100.120683, 15.715997]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.132914, 15.717717, 100.134019, 15.718538], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.132914, 15.717717], [100.132914, 15.718538], [100.134019, 15.718538], [100.134019, 15.717717], [100.132914, 15.717717]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.13212, 15.713514, 100.132951, 15.713947], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.13212, 15.713514], [100.13212, 15.713947], [100.132951, 15.713947], [100.132951, 15.713514], [100.13212, 15.713514]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.134963, 15.712553, 100.135869, 15.713002], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.134963, 15.712754], [100.135043, 15.712553], [100.135869, 15.712816], [100.135805, 15.713002], [100.134963, 15.712754]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.133917, 15.71246, 100.134518, 15.712884], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.133954, 15.712718], [100.134437, 15.712884], [100.134518, 15.712718], [100.134394, 15.712641], [100.134432, 15.712543], [100.134287, 15.71246], [100.134003, 15.712594], [100.133917, 15.712662], [100.133954, 15.712718]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.123757, 15.70586, 100.124518, 15.706315], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.123757, 15.70586], [100.123757, 15.706315], [100.124518, 15.706315], [100.124518, 15.70586], [100.123757, 15.70586]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.124186, 15.707993, 100.12499, 15.708701], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.124186, 15.707993], [100.124186, 15.708701], [100.12499, 15.708701], [100.12499, 15.707993], [100.124186, 15.707993]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.124668, 15.709315, 100.124974, 15.709506], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.124668, 15.709315], [100.124668, 15.709506], [100.124974, 15.709506], [100.124974, 15.709315], [100.124668, 15.709315]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.12602, 15.709857, 100.126369, 15.710105], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.12602, 15.709857], [100.12602, 15.710105], [100.126369, 15.710105], [100.126369, 15.709857], [100.12602, 15.709857]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;8&quot;, &quot;properties&quot;: {&quot;class&quot;: 111}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [100.132908, 15.706945, 100.133262, 15.707183], &quot;geometry&

# %% [markdown]
# ### Convert geographic coordinate system
# - This case study convert the CRS from EPSG:4326(degree) to EPSG:32647(meter)

# %%
# check coordinate system of data
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
from dream_river.geobox import convert_geojson_CRS

# set input output path
input_path = 'training/training_data.geojson'
output_path = 'training/training_32647.geojson'

# function to convert CRS
convert_geojson_CRS(input_path, output_path, crs=32647)

# %%
# Load input data shapefile
input1 = gpd.read_file(output_path)

# checl crs
input1.crs
# Out:
# <Derived Projected CRS: EPSG:32647>
# Name: WGS 84 / UTM zone 47N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 96°E and 102°E, northern hemisphere between equator and 84°N, onshore and offshore. China. Indonesia. Laos. Malaysia - West Malaysia. Mongolia. Myanmar (Burma). Russian Federation. Thailand.
# - bounds: (96.0, 0.0, 102.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 47N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
