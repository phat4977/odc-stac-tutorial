# %% [markdown]
# # Load dataset from Datacube/ plot image and export to GeoTiff <img align="right" src="image/gistda.png" width="200" height="200">
# - load/plot/export data using get_image()
#
#
# <table class="ee-notebook-buttons" align="left">
#     <td><a target="_parent"  href="https://nbviewer.org/github/Pathakorn40/rice-detection/blob/main/Tutorial/Get_data.ipynb"><img width=26px src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/883px-Jupyter_logo.svg.png" />Notebook Viewer</a></td>
# </table>

# %% [markdown]
# ### Load package

# %%
from dream_river.plotimg import get_img
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Set parameter

# %%
# query  dataset from datacube
query = {"product": "ls8_collections_sr_scene",
         "measurements": ["red", "green", "blue","nir"],
         "y": (11.75, 11.85),
         "x": (99.74, 99.84),
         "time": ("2015-01-01","2015-02-28"),
         "resolution": (-30,30),
         "output_crs": "EPSG:32647"
        }

# assign output file path and file name in geotiff 
filename = "training/example.tiff"

# %% [markdown]
#  the result will show the num of timesteps and get selected timestep from user.
#
#
# wait a minute for export file,the output file will export in same directory of this notebook file.

# %% [markdown]
# ### Export satellite image selected
# when you run this code the program will show the example of satellite images and ask you to select the timesteps of Images that you want.

# %% [markdown]
# In this case, We select image frist timestep that is index = 0.

# %%
# load/plot/export data function
plot = get_img(query, filename)
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 4, y: 371, x: 365)
# Coordinates:
#   * time         (time) datetime64[ns] 2015-01-04T03:38:36 ... 2015-02-21T03:...
#   * y            (y) float64 1.31e+06 1.31e+06 1.31e+06 ... 1.299e+06 1.299e+06
#   * x            (x) float64 5.806e+05 5.806e+05 ... 5.915e+05 5.915e+05
#     spatial_ref  int32 32647
# Data variables:
#     red          (time, y, x) int16 1377 1312 967 827 762 ... 164 154 166 156
#     green        (time, y, x) int16 1105 1073 871 764 706 ... 411 402 402 388
#     blue         (time, y, x) int16 739 674 462 391 334 ... 415 414 408 410 399
#     nir          (time, y, x) int16 2537 2986 3506 3146 2965 ... 100 90 102 101
# Attributes:
#     crs:           EPSG:32647
#     grid_mapping:  spatial_ref
# --------------------------------------------------
# --------------------------------------------------
# There are:_ 4_timesteps
# Choose the timestep that you want like: [0,1,2,...]  0
